# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git remote add origin https://github.com/vaishak-pce/NM392_SATTVA.git

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/vaishak-pce/NM392_SATTVA.git'

# %%
# !pip install GDAL

# %%
# !pip install richdem
# Out:
# ...
#      |████████████████████████████████| 4.5MB 5.5MB/s
# ...

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import richdem as rd

# %%
matplotlib.rcParams['figure.figsize'] = (8, 5.5)

# %%
dempath='/dem1_cont.tif'
dem=rd.LoadGDAL(dempath)

# %%
plt.imshow(dem, interpolation='none')
plt.colorbar()
plt.show()
